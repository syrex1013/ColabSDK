# %% [markdown]
# # ColabSDK Test Notebook
#
# Open this notebook with the SDK to validate connectivity, output capture, plotting, and GPU detection.

# %%
print('ColabSDK connected')
import sys
print('Python', sys.version)

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [1, 4, 9])
plt.title('ColabSDK plot test')
plt.show()

# %%
try:
    import torch
    print('CUDA available:', torch.cuda.is_available())
    if torch.cuda.is_available():
        print('GPU:', torch.cuda.get_device_name(0))
except ImportError:
    print('torch not installed')
